# %% [markdown]
# # Automated Testing using 11 tests!

# %%
# !pip install pytest pytest-cov

# %%
import os
import sys

ROOT_DIR = "/content/drive/MyDrive/SciProgr2025_Assign1_Avinash_Flavio"
os.chdir(ROOT_DIR)
sys.path.append(os.path.join(ROOT_DIR, "src"))
print("Current directory:", os.getcwd())

# %%
# !pytest -v

# %%
# import sys
# sys.path.append("src")
