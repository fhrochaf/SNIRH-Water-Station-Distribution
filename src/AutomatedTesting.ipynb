# %% [markdown]
# # Automated Testing using 11 tests!

# %%
import os
import sys
PROJECT_ROOT = "/content/drive/MyDrive/SciProgr2025_Assign1_Avinash_Flavio"
os.chdir(PROJECT_ROOT)
sys.path.append(os.path.join(PROJECT_ROOT, "src"))
print("Current directory:", os.getcwd())

# %%
# !pip install pytest pytest-cov

# %%
import sys
sys.path.append("src")
# !pytest -v
